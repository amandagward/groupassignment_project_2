# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')
df.head()
# Out:
#   areaname        regname      country             devname   lat   lon  \
# 0     Asia  Southern Asia  Afghanistan  Developing regions  33.0  65.0
# 1     Asia  Southern Asia  Afghanistan  Developing regions  33.0  65.0
# 2     Asia  Southern Asia  Afghanistan  Developing regions  33.0  65.0
# 3     Asia  Southern Asia  Afghanistan  Developing regions  33.0  65.0
# 4     Asia  Southern Asia  Afghanistan  Developing regions  33.0  65.0
#
#                                     flag capital  population countrycode  \
# 0  https://restcountries.eu/data/afg.svg   Kabul    27657145          AF
# 1  https://restcountries.eu/data/afg.svg   Kabul    27657145          AF
# 2  https://restcountries.eu/data/afg.svg   Kabul    27657145          AF
# 3  https://restcountries.eu/data/afg.svg   Kabul    27657145          AF
# 4  https://restcountries.eu/data/afg.svg   Kabul    27657145          AF
#
#    year  value
# 0  1980     16
# 1  1981     39
# 2  1982     39
# 3  1983     47
# 4  1984     71

# %%
sr = df.groupby(['regname','year']).sum()
sr.to_csv('sr.csv', header=True)

# %%
sr
# Out:
#                                        lat         lon  population  value
# regname                   year
# Australia and New Zealand 1980  -68.000000  307.000000    28815214   1304
#                           1981  -68.000000  307.000000    28815214   1119
#                           1982  -68.000000  307.000000    28815214    848
#                           1983  -68.000000  307.000000    28815214    457
#                           1984  -68.000000  307.000000    28815214    481
#                           1985  -68.000000  307.000000    28815214    467
#                           1986  -68.000000  307.000000    28815214    532
#                           1987  -68.000000  307.000000    28815214    675
#                           1988  -68.000000  307.000000    28815214    610
#                           1989  -68.000000  307.000000    28815214    790
#                           1990  -68.000000  307.000000    28815214    890
# ...

# %%
dev = df.groupby(['devname','year']).sum()
dev.to_csv('dev.csv', header=True)
